# %% [markdown]
# ASSIGNMENT - 4
#
# Name: Akshit Bahl <br>
# Reg. No.: 21BIT0012
#
# AI ML Evening Batch
#
# VIT University, Vellore Campus<br>
# Branch: Information Technology
#
# Date: 01.10.2023
#
# Email Id: akshit.bahl2021@vitstudent.ac.in <br>
# Contact: 9643973760

# %%
#importing all the necessary libraries and packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# First We have imported our 'winequality-red' dataset into our colab notebook.
#
# Now we just print the head of the dataFrame.

# %%
df=pd.read_csv('/content/winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# so there are a total of 1599 observations and 12 features in our dataset.

# %% [markdown]
# <h1>UNIVARIATE ANALYSIS</h1>
#
# <h3>Data Visualization
#
# 1.Histogram </h3>

# %%
# Choose the feature (column) you want to create a histogram for
feature_name = 'residual sugar'

# Plot the histogram
plt.hist(df[feature_name], bins=20)  # You can adjust the number of bins as needed
plt.xlabel(feature_name)
plt.ylabel('Frequency')
plt.title('Histogram of the residual sugar')
plt.show()

# %%
#we can also add various paramaters into the 'hist' function

plt.hist(df['free sulfur dioxide'],bins='stone',orientation='horizontal',color='yellow')
plt.xlabel('free sulfur dioxide of wine')
plt.ylabel('frequency')
plt.title('free sulfur dioxide of wine')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/histograms.py:793: RuntimeWarning: The number of bins estimated may be suboptimal.
#   bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)

# %%
#using seaborn

sns.histplot(data=df, x='pH', bins=10, edgecolor='black', color='black')  # You can adjust the number of bins as needed
plt.xlabel('pH of wine')
plt.ylabel('Frequency')
plt.title('Histogram of pH of wine')
plt.show()

# %% [markdown]
# <h3> 2. Pie Plot</h3>

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df['quality'].nunique()
# Out:
# 6

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
plt.pie(df['quality'].value_counts(),[0,0.1,0,0.1,0,0.1],labels=[5, 6, 7, 4, 8, 3],autopct='%1.1f%%',colors=['pink','yellow','purple','blue','green','black'],shadow=True)
plt.title('Quality of wine')
plt.show()

# %% [markdown]
# 3. BARPLOT

# %%
sns.barplot(x=df.pH.value_counts().index,y=df.pH.value_counts())
# Out:
# <Axes: ylabel='pH'>

# %% [markdown]
# ###BIVARIATE ANALYSIS

# %% [markdown]
# 1. lineplot

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Line plot using Matplotlib
plt.plot(df['chlorides'], df['citric acid'], marker='o', linestyle='-')
plt.xlabel('chlorides')
plt.ylabel('citric acid')
plt.title('Line Plot of chlorides over citric acid of wine')
plt.grid(True)
plt.show()

# %%
#using seaborn

sns.lineplot(x='pH', y='citric acid', data=df, marker='o')
plt.xlabel('pH')
plt.ylabel('citric acid')
plt.title('Line Plot of pH over citric acid of wine')
plt.grid(True)
plt.show()

# %% [markdown]
# <h3> 2. SCATTER PLOT </h3>

# %%
xfeature="volatile acidity"
yfeature="sulphates"

sns.scatterplot(x=xfeature, y=yfeature, data=df)
plt.xlabel(xfeature)
plt.ylabel(yfeature)
plt.title('Scatter Plot of volatile acidity over sulphates of wine')
plt.show()

# %%
xfeature="residual sugar"
yfeature="pH"

sns.scatterplot(x=xfeature, y=yfeature, data=df)
plt.xlabel(xfeature)
plt.ylabel(yfeature)
plt.title('Scatter Plot of residual sugar vs pH ')
plt.show()

# %% [markdown]
# ###Multi-variate Analysis

# %% [markdown]
# <h3>1. PAIR PLOT</h3>

# %%
# Pair plot using Seaborn
sns.pairplot(df)
plt.suptitle('Pair Plot of df dataset', y=1.02)
plt.show()

# %% [markdown]
# <h3>2. HEATMAP</h3>

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(),annot=True, cmap="coolwarm", linewidths=5.0)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ###TASK 4: Descriptive Statistics

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# ###Handling Null Values in dataset

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Check for missing values
missing_values = df.isna()
print(missing_values)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
# Replace null values with either mean, median or mode
# df['pH'].fillna(df['pH'].mean(),inplace=True)

# %% [markdown]
# ###Outlier detection and Removal

# %%
sns.boxplot(df.pH)
# Out:
# <Axes: >

# %%
#so we will replace these outliers with median
q1=df.pH.quantile(0.25)
q3=df.pH.quantile(0.75)
iqr=q3-q1
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

df.median()
# Out:
# fixed acidity            7.90000
# volatile acidity         0.52000
# citric acid              0.26000
# residual sugar           2.20000
# chlorides                0.07900
# free sulfur dioxide     14.00000
# total sulfur dioxide    38.00000
# density                  0.99675
# pH                       3.31000
# sulphates                0.62000
# alcohol                 10.20000
# quality                  6.00000
# dtype: float64

# %%
#pH column median is 3.31
df.pH=np.where(df.pH > upper_limit, 7.9, df.pH)
df.pH=np.where(df.pH < lower_limit, 7.9, df.pH)

# %%
sns.boxplot(df.pH)
# Out:
# <Axes: >

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
sns.boxplot(df['fixed acidity'])
# Out:
# <Axes: >

# %%
#so we will replace these outliers with median
q1=df['fixed acidity'].quantile(0.25)
q3=df['fixed acidity'].quantile(0.75)
iqr=q3-q1
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

df.median()
# Out:
# fixed acidity            7.90000
# volatile acidity         0.52000
# citric acid              0.26000
# residual sugar           2.20000
# chlorides                0.07900
# free sulfur dioxide     14.00000
# total sulfur dioxide    38.00000
# density                  0.99675
# pH                       3.31000
# sulphates                0.62000
# alcohol                 10.20000
# quality                  6.00000
# dtype: float64

# %%
#pH column median is 3.31
df['fixed acidity']=np.where(df['fixed acidity'] > upper_limit, 7.9, df['fixed acidity'])
#df.pH=np.where(df.pH < lower_limit, 7.9, df.pH)

# %%
sns.boxplot(df['fixed acidity'])
# Out:
# <Axes: >

# %%
df.median()
# Out:
# fixed acidity            7.90000
# volatile acidity         0.52000
# citric acid              0.26000
# residual sugar           2.20000
# chlorides                0.07900
# free sulfur dioxide     14.00000
# total sulfur dioxide    38.00000
# density                  0.99675
# pH                       3.31000
# sulphates                0.62000
# alcohol                 10.20000
# quality                  6.00000
# dtype: float64

# %%
sns.boxplot(df['volatile acidity'])
# Out:
# <Axes: >

# %%
#so we will replace these outliers with median
q1=df['volatile acidity'].quantile(0.25)
q3=df['volatile acidity'].quantile(0.75)
iqr=q3-q1
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

df.median()
# Out:
# fixed acidity            7.90000
# volatile acidity         0.52000
# citric acid              0.26000
# residual sugar           2.20000
# chlorides                0.07900
# free sulfur dioxide     14.00000
# total sulfur dioxide    38.00000
# density                  0.99675
# pH                       3.31000
# sulphates                0.62000
# alcohol                 10.20000
# quality                  6.00000
# dtype: float64

# %%
df['volatile acidity']=np.where(df['volatile acidity'] > upper_limit, 0.52, df['volatile acidity'])
sns.boxplot(df['volatile acidity'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['citric acid'])
# Out:
# <Axes: >

# %%
q1=df['citric acid'].quantile(0.25)
q3=df['citric acid'].quantile(0.75)
iqr=q3-q1
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

df['citric acid']=np.where(df['citric acid'] > upper_limit, 0.26, df['citric acid'])
sns.boxplot(df['citric acid'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['residual sugar'])
# Out:
# <Axes: >

# %%
#so we will replace these outliers with median
q1=df['residual sugar'].quantile(0.25)
q3=df['residual sugar'].quantile(0.75)
iqr=q3-q1
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

df.median()

df['residual sugar']=np.where(df['residual sugar'] > upper_limit, 2.20, df['residual sugar'])
df['residual sugar']=np.where(df['residual sugar'] < lower_limit, 2.20, df['residual sugar'])
sns.boxplot(df['residual sugar'])
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
sns.boxplot(df['chlorides'])
# Out:
# <Axes: >

# %%
#so we will replace these outliers with median
q1=df['chlorides'].quantile(0.25)
q3=df['chlorides'].quantile(0.75)
iqr=q3-q1
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

df.median()

df['chlorides']=np.where(df['chlorides'] > upper_limit, 0.079, df['chlorides'])
df['chlorides']=np.where(df['chlorides'] < lower_limit, 0.079, df['chlorides'])
sns.boxplot(df['chlorides'])
# Out:
# <Axes: >

# %%
df.median()
# Out:
# fixed acidity            7.90000
# volatile acidity         0.52000
# citric acid              0.26000
# residual sugar           2.20000
# chlorides                0.07900
# free sulfur dioxide     14.00000
# total sulfur dioxide    38.00000
# density                  0.99675
# pH                       3.31000
# sulphates                0.62000
# alcohol                 10.20000
# quality                  6.00000
# dtype: float64

# %%
sns.boxplot(df['free sulfur dioxide'])
# Out:
# <Axes: >

# %%
#so we will replace these outliers with median
q1=df['free sulfur dioxide'].quantile(0.25)
q3=df['free sulfur dioxide'].quantile(0.75)
iqr=q3-q1
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

df.median()

df['free sulfur dioxide']=np.where(df['free sulfur dioxide'] > upper_limit, 14, df['free sulfur dioxide'])
#df['free sulfur dioxide']=np.where(df['free sulfur dioxide'] < lower_limit, 0.079, df['free sulfur dioxide'])
sns.boxplot(df['free sulfur dioxide'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['total sulfur dioxide'])
# Out:
# <Axes: >

# %%
#so we will replace these outliers with median
q1=df['total sulfur dioxide'].quantile(0.25)
q3=df['total sulfur dioxide'].quantile(0.75)
iqr=q3-q1
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

df.median()

df['total sulfur dioxide']=np.where(df['total sulfur dioxide'] > upper_limit, 38, df['total sulfur dioxide'])
#df['free sulfur dioxide']=np.where(df['free sulfur dioxide'] < lower_limit, 0.079, df['free sulfur dioxide'])
sns.boxplot(df['total sulfur dioxide'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['density'])
# Out:
# <Axes: >

# %%
#so we will replace these outliers with median
q1=df['density'].quantile(0.25)
q3=df['density'].quantile(0.75)
iqr=q3-q1
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

df.median()

df['density']=np.where(df['density'] > upper_limit, 0.996, df['density'])
df['density']=np.where(df['density'] < lower_limit, 0.996, df['density'])
sns.boxplot(df['density'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['sulphates'])
# Out:
# <Axes: >

# %%
df.median()
# Out:
# fixed acidity            7.90000
# volatile acidity         0.52000
# citric acid              0.26000
# residual sugar           2.20000
# chlorides                0.07900
# free sulfur dioxide     14.00000
# total sulfur dioxide    38.00000
# density                  0.99668
# pH                       3.31000
# sulphates                0.62000
# alcohol                 10.20000
# quality                  6.00000
# dtype: float64

# %%
#so we will replace these outliers with median
q1=df['sulphates'].quantile(0.25)
q3=df['sulphates'].quantile(0.75)
iqr=q3-q1
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

df.median()

df['sulphates']=np.where(df['sulphates'] > upper_limit, 0.62, df['sulphates'])
#df['free sulfur dioxide']=np.where(df['free sulfur dioxide'] < lower_limit, 0.079, df['free sulfur dioxide'])
sns.boxplot(df['sulphates'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['alcohol'])
# Out:
# <Axes: >

# %%
#so we will replace these outliers with median
q1=df['alcohol'].quantile(0.25)
q3=df['alcohol'].quantile(0.75)
iqr=q3-q1
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr

df.median()

df['alcohol']=np.where(df['alcohol'] > upper_limit, 10.2, df['alcohol'])
#df['free sulfur dioxide']=np.where(df['free sulfur dioxide'] < lower_limit, 0.079, df['free sulfur dioxide'])
sns.boxplot(df['alcohol'])
# Out:
# <Axes: >

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
#now we see that almost every column has been replaced its outliers.

# %% [markdown]
# ###Here target is 'quality of wine'

# %% [markdown]
# The dependent variable is 'quality' and the independent variables are all of the rest.

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# Checking the correlation of independent variables with the target

# %% [markdown]
# In our dataset, there are no categorical columns present so we don't have to encode the categorical columns.

# %% [markdown]
# Now checking correlation of independent variables with the target (quality)

# %%
df.corr().quality.sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.464152
# sulphates               0.385729
# citric acid             0.232209
# fixed acidity           0.109637
# residual sugar          0.035506
# pH                      0.009208
# free sulfur dioxide    -0.047187
# chlorides              -0.162122
# total sulfur dioxide   -0.168010
# density                -0.171273
# volatile acidity       -0.356247
# Name: quality, dtype: float64

# %% [markdown]
# <h1> So we have first distinguished between the Dependent and Independent Variables which are as follows:
#
# 1. 'quality' of the wine to be predicted.
# 2. all rest of the categories are the predictors.
#
#
# <h1>We have checked the correlation between the independent and the target variable</h1>

# %%
#Splitting the dependent and independent variables from the dataset

y=df.quality
y.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
X=df.drop(columns=['quality'],axis=1)
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %% [markdown]
# ###SCALING OUR DATASET

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()

# %%
X_scaled=pd.DataFrame(scale.fit_transform(X),columns=X.columns)

# %%
X_scaled.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.363636          0.651685     0.000000        0.363636   0.448718
# 1       0.415584          0.853933     0.000000        0.618182   0.730769
# 2       0.415584          0.719101     0.050633        0.509091   0.653846
# 3       0.857143          0.179775     0.708861        0.363636   0.435897
# 4       0.363636          0.651685     0.000000        0.363636   0.448718
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.243902              0.241379  0.630058  0.116700   0.348485
# 1             0.585366              0.525862  0.514451  0.054326   0.530303
# 2             0.341463              0.413793  0.537572  0.066398   0.484848
# 3             0.390244              0.465517  0.653179  0.046278   0.378788
# 4             0.243902              0.241379  0.630058  0.116700   0.348485
#
#     alcohol
# 0  0.196078
# 1  0.274510
# 2  0.274510
# ...

# %% [markdown]
# SCALING IS DONE

# %% [markdown]
# ###TRAIN AND TEST SPLIT

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (1279, 11)

# %%
x_test.shape
# Out:
# (320, 11)

# %%
y_train.shape
# Out:
# (1279,)

# %%
y_test.shape
# Out:
# (320,)

# %% [markdown]
# NOW WE NEED TO BALANCE OUR DATA USING SMOTE

# %% [markdown]
# ###Balancing data using SMOTE

# %%
from imblearn.over_sampling import SMOTE
smote=SMOTE()

# %%
x_train_smote,y_train_smote=smote.fit_resample(x_train,y_train)

# %%
y_train.value_counts()
# Out:
# 5    546
# 6    496
# 7    172
# 4     42
# 8     15
# 3      8
# Name: quality, dtype: int64

# %%
y_train_smote.value_counts()
# Out:
# 5    546
# 8    546
# 6    546
# 7    546
# 4    546
# 3    546
# Name: quality, dtype: int64

# %% [markdown]
# SO OUR DATA IS BALANCED NOW.

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train_smote,y_train_smote)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
y_pred_train=lr.predict(x_train_smote)

# %%
#compare
quality=pd.DataFrame({'Actual quality':y_test,'Predicted Quality':y_pred})

# %%
quality
# Out:
#       Actual quality  Predicted Quality
# 1109               6           6.455091
# 1032               5           2.891763
# 1002               7           7.767304
# 487                6           4.126084
# 979                5           5.883120
# ...              ...                ...
# 794                6           7.219377
# 813                4           5.723191
# 1322               5           6.713361
# 704                4           3.368839
# 1023               6           6.468748
#
# [320 rows x 2 columns]

# %% [markdown]
# ###testing with random values

# %%
X_scaled.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.363636          0.651685     0.000000        0.363636   0.448718
# 1       0.415584          0.853933     0.000000        0.618182   0.730769
# 2       0.415584          0.719101     0.050633        0.509091   0.653846
# 3       0.857143          0.179775     0.708861        0.363636   0.435897
# 4       0.363636          0.651685     0.000000        0.363636   0.448718
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.243902              0.241379  0.630058  0.116700   0.348485
# 1             0.585366              0.525862  0.514451  0.054326   0.530303
# 2             0.341463              0.413793  0.537572  0.066398   0.484848
# 3             0.390244              0.465517  0.653179  0.046278   0.378788
# 4             0.243902              0.241379  0.630058  0.116700   0.348485
#
#     alcohol
# 0  0.196078
# 1  0.274510
# 2  0.274510
# ...

# %%
lr.predict([[0.415584,0.719101,0.050633,0.509091,0.653846,0.341463,0.413793,0.537572,0.066398,0.484848,0.274510]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.3276855])

# %% [markdown]
# THE CONTINOUS LINEAR REGRESSION IS NOT A GOOD CHOICE FOR THE CLASSIFICATION DATASET.

# %% [markdown]
# ###Evaluation metrics of the ML Model

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
from sklearn import metrics

# %%
print(metrics.r2_score(y_test,y_pred))
# Out:
# -0.9049277433936045

# %% [markdown]
# <h1>The Accuracy of our ML model is approximately 34%. This means that we have not chosen a correct ML model, so we will now do it with 'LogisticRegression'.</h1>

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression(max_iter=1000)

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([6, 5, 7, 5, 6, 5, 5, 6, 5, 5, 5, 5, 6, 6, 6, 7, 7, 5, 6, 5, 6, 5,
#        6, 6, 5, 5, 5, 7, 5, 6, 6, 6, 6, 5, 6, 6, 5, 6, 6, 6, 5, 6, 5, 7,
#        6, 5, 5, 6, 5, 6, 5, 5, 5, 6, 6, 5, 5, 5, 7, 5, 5, 6, 6, 6, 5, 6,
#        5, 6, 6, 6, 5, 5, 5, 5, 5, 6, 5, 5, 6, 7, 5, 5, 6, 6, 5, 5, 6, 5,
#        5, 5, 5, 5, 6, 5, 6, 5, 6, 5, 5, 5, 7, 6, 6, 7, 5, 5, 5, 5, 6, 5,
#        6, 5, 6, 5, 6, 6, 6, 6, 6, 6, 5, 6, 5, 5, 6, 6, 5, 5, 6, 7, 5, 5,
#        6, 6, 6, 5, 6, 5, 6, 5, 6, 5, 5, 6, 5, 6, 6, 7, 6, 5, 6, 6, 5, 5,
#        6, 5, 5, 5, 6, 6, 6, 6, 7, 5, 6, 5, 6, 6, 5, 6, 6, 6, 5, 7, 6, 6,
#        6, 7, 6, 5, 5, 6, 5, 6, 7, 5, 5, 6, 5, 6, 6, 6, 5, 5, 5, 5, 5, 5,
#        5, 6, 5, 6, 5, 5, 5, 5, 5, 6, 6, 5, 6, 6, 5, 7, 5, 6, 5, 6, 6, 5,
#        5, 6, 6, 6, 5, 6, 6, 6, 5, 5, 5, 6, 5, 6, 6, 6, 6, 7, 7, 6, 5, 5,
#        5, 5, 6, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 6, 5, 5,
#        5, 5, 5, 5, 6, 7, 5, 6, 5, 6, 6, 6, 6, 5, 7, 7, 5, 6, 6, 6, 6, 5,
# ...

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score, roc_curve

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.61875

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[  0,   0,   2,   0,   0,   0],
#        [  0,   0,   7,   4,   0,   0],
#        [  0,   0, 105,  29,   1,   0],
#        [  0,   0,  46,  85,  11,   0],
#        [  0,   0,   2,  17,   8,   0],
#        [  0,   0,   0,   1,   2,   0]])

# %%
pd.crosstab(y_test,y_pred)
# Out:
# col_0      5   6   7
# quality
# 3          2   0   0
# 4          7   4   0
# 5        105  29   1
# 6         46  85  11
# 7          2  17   8
# 8          0   1   2

# %%
105+85+8
# Out:
# 198

# %%
198/(2+7+4+105+29+1+46+85+11+2+17+8+1+2)
# Out:
# 0.61875

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        11
#            5       0.65      0.78      0.71       135
#            6       0.62      0.60      0.61       142
#            7       0.36      0.30      0.33        27
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.62       320
#    macro avg       0.27      0.28      0.27       320
# weighted avg       0.58      0.62      0.60       320
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
probability=model.predict_proba(x_test)[:,1]
probability
# Out:
# array([0.01378812, 0.07775242, 0.00555417, 0.08131724, 0.02937408,
#        0.01918951, 0.05919127, 0.01191945, 0.09859708, 0.02220789,
#        0.03387683, 0.05048627, 0.05477384, 0.0483359 , 0.04878008,
#        0.00526697, 0.00644716, 0.03676276, 0.07304273, 0.0453265 ,
#        0.04439677, 0.02980047, 0.0505086 , 0.02098772, 0.02563604,
#        0.04928044, 0.02226239, 0.00836161, 0.01091382, 0.05654648,
#        0.0188786 , 0.01630419, 0.04114789, 0.04040687, 0.08688093,
#        0.01165331, 0.01770574, 0.04537269, 0.01967314, 0.05241005,
#        0.02716175, 0.03307517, 0.0180672 , 0.00488517, 0.03299181,
#        0.02706398, 0.05657854, 0.0120345 , 0.03249875, 0.01119551,
#        0.04261521, 0.01822127, 0.02401095, 0.01380339, 0.01677436,
#        0.02534959, 0.02923835, 0.04304423, 0.00826124, 0.02813406,
#        0.0451462 , 0.03329552, 0.03616484, 0.03043174, 0.05276542,
#        0.02954553, 0.06604562, 0.04827197, 0.01280314, 0.03287733,
# ...

# %%
fpr,tpr,thresholds=roc_curve(y_test,probability)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-116-88953f208d1a> in <cell line: 13>()
#      12
#      13 for i in range(n_classes):
# ---> 14     fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], probability[:, i])  # Replace "probability" with your predicted probabilities
#      15     roc_auc[i] = auc(fpr[i], tpr[i])
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
roc_auc_score(y_test,probability)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-fcfc476b725b> in <cell line: 1>()
# ----> 1 roc_auc_score(y_test,probability)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     563             )
#     564         if multi_class == "raise":
# --> 565             raise ValueError("multi_class must be in ('ovo', 'ovr')")
#     566         return _multiclass_roc_auc_score(
#     567             y_true, y_score, labels, multi_class, average, sample_weight
#
# ValueError: multi_class must be in ('ovo', 'ovr')

# %% [markdown]
# So The accuracy is coming out to be 62%, which is not satisfactory.

# %% [markdown]
# So, Now we will move on to another ML models.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
tree_model = DecisionTreeClassifier()
tree_model.fit(x_train, y_train)
tree_predictions = tree_model.predict(x_test)

# %%
# Evaluation of Decision Tree model
tree_accuracy = accuracy_score(y_test, tree_predictions)
tree_report = classification_report(y_test, tree_predictions)

print("Decision Tree Model Accuracy:", tree_accuracy)
print("Decision Tree Model Classification Report:")
print(tree_report)
# Out:
# Decision Tree Model Accuracy: 0.640625
# Decision Tree Model Classification Report:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.18      0.18      0.18        11
#            5       0.76      0.70      0.73       135
#            6       0.66      0.65      0.65       142
#            7       0.40      0.63      0.49        27
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.64       320
#    macro avg       0.33      0.36      0.34       320
# weighted avg       0.66      0.64      0.65       320
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# <h1>The decision tree ML model accuracy is 64%.</h1>

# %% [markdown]
# RANDOM FOREST

# %%
forest_model = RandomForestClassifier()
forest_model.fit(x_train, y_train)
forest_predictions = forest_model.predict(x_test)

# Evaluation of Random Forest model
random_forest_accuracy = accuracy_score(y_test, forest_predictions)
random_forest_report = classification_report(y_test, forest_predictions)

print("Random Forest Model Accuracy:", random_forest_accuracy)
print("Random Forest Model Classification Report:")
print(random_forest_report)
# Out:
# Random Forest Model Accuracy: 0.734375
# Random Forest Model Classification Report:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        11
#            5       0.74      0.84      0.79       135
#            6       0.76      0.73      0.74       142
#            7       0.60      0.67      0.63        27
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.73       320
#    macro avg       0.35      0.37      0.36       320
# weighted avg       0.70      0.73      0.71       320
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# <h1>So the final accuracy of the Random Forest ML Model comes out to be 73%, which is satisfactory.</h1>

# %%
 confusion_matrix(y_test,forest_predictions)
# Out:
# array([[  0,   0,   1,   1,   0,   0],
#        [  0,   0,   8,   3,   0,   0],
#        [  0,   0, 114,  20,   1,   0],
#        [  0,   0,  30, 103,   9,   0],
#        [  0,   0,   1,   8,  18,   0],
#        [  0,   0,   0,   1,   2,   0]])

# %%
pd.crosstab(y_test,forest_predictions)
# Out:
# col_0      5    6   7
# quality
# 3          1    1   0
# 4          8    3   0
# 5        114   20   1
# 6         30  103   9
# 7          1    8  18
# 8          0    1   2

# %% [markdown]
# ASSIGNMENT - 4
#
# Name: Akshit Bahl <br>
# Reg. No.: 21BIT0012
#
# AI ML Evening Batch
#
# VIT University, Vellore Campus<br>
# Branch: Information Technology
#
# Date: 01.10.23
#
# Email Id: akshit.bahl2021@vitstudent.ac.in <br>
# Contact: 9643973760
